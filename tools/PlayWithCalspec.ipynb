# %% [markdown]
# # Use CALSPEC with getCalspec

# %% [markdown]
# ## To get all Calspec data in one time in cache, write

# %%
from getCalspec.rebuild import rebuild_cache

# %%
# rebuild_cache()

# %% [markdown]
# # When the STSC webpage is updated, it might be necessary to rebuild the calspec_data/calspec.csv table and the cache:

# %%
from getCalspec.rebuild import rebuild_tables, rebuild_cache
#rebuild_tables()
#rebuild_cache()

# %% [markdown]
# ## The main function query the Calspec table located in calspec_data/calspec.csv to download spectrum FITS files from STSC archive.

# %%
from getCalspec.getCalspec import *

# %%
dir()
# Out:
# ['Calspec',
#  'In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_calspec_keys',
#  'get_ipython',
#  'is_calspec',
#  'quit',
#  'rebuild_cache',
#  'rebuild_tables']

# %%
test = is_calspec("eta1 dor")
c = Calspec("eta1 dor")
c.get_spectrum_fits_filename()  # download the fits file
c.get_spectrum_table()  # download and return an Astropy table
c.get_spectrum_numpy()  # download and return a dictionnary of numpy arrays with units
c.plot_spectrum()  # download and plot the spectrum

# %% [markdown]
# # Retrieve all calspec

# %%
from getCalspec.getCalspec import getCalspecDataFrame

# %%
df = getCalspecDataFrame()

# %%
df
# Out:
#      Unnamed: 0   Star_name   Sp_T       V    B_V           Name     Model  \
# 0             0     109 VIR  A0III    3.73  -0.01         109vir  _mod_003
# 1             1      10 LAC    O9V    4.88  -0.21          10lac  _mod_005
# 2             2    16 CYG B    G3V    6.20   0.66         16cygb  _mod_003
# 3             3      18 SCO    G2V    5.50   0.65          18sco  _mod_004
# 4             4     1732526    A4V   12.53   0.12        1732526  _mod_005
# ..          ...         ...    ...     ...    ...            ...       ...
# 126         126         SUN    G2V  -26.75   0.63  sun_reference       NaN
# 127         127         SUN    G2V  -26.75   0.63            sun  _mod_001
# 128         128  WD0320-539     DA    14.9    ...     wd0320_539  _mod_001
# 129         129  WD0947+857     DA    16.4    ...     wd0947_857  _mod_003
# 130         130  WD1026+453     DA   16.13  -0.04     wd1026_453  _mod_003
#
#              STIS Var_(%)            RA          Decl    Vr      PM    PM.1  \
# 0       _stis_003     NaN  14 46 14.925  +01 53 34.38  -6.1 -114.03  -22.13
# 1       _stis_007   <0.23  22 39 15.679  +39 03 00.97 -10.0   -0.32   -5.46
# 2       _stis_003   <0.21  19 41 51.973  +50 31 03.09 -27.7 -134.79 -162.49
# 3       _stis_004     NaN  16 15 37.270  -08 22 09.98  11.9  232.16 -495.37
# 4    _stisnic_007    1.40  17 32 52.630  +71 04 43.12   NaN    0.22   -2.71
# ..            ...     ...           ...           ...   ...     ...     ...
# 126    _stis_002*     NaN           NaN           NaN   NaN     NaN     NaN
# 127           NaN     NaN           NaN           NaN   NaN     NaN     NaN
# 128     _stis_005     NaN  03 22 14.820  -53 45 16.47  57.8    6.56  -59.93
# 129     _stis_006     NaN  09 57 54.296  +85 29 40.88   NaN  -28.13  -27.27
# 130     _stis_006     NaN  10 29 45.295  +45 07 04.93   NaN  -90.46    1.68
#
#                  Simbad_Name  Alt_Simbad_Name  Astroquery_Name Alt_Star_name  \
# 0                   HD130109              NaN        * 109 VIR           NaN
# 1                        NaN              NaN        *  10 LAC           NaN
# 2                   HD186427              NaN      *  16 CYG B           NaN
# 3                   HD146233              NaN        *  18 SCO           NaN
# 4    2MASS J17325264+7104431  TYC 4424-1286-1  TYC 4424-1286-1           NaN
# ..                       ...              ...              ...           ...
# 126                      NaN              NaN              NaN           NaN
# 127                      NaN              NaN              NaN           NaN
# 128                      NaN              NaN         LB  1663           NaN
# 129                      NaN              NaN  RX J0957.8+8529           NaN
# 130                      NaN              NaN      PG 1026+454           NaN
#
#       HD_name
# 0    HD130109
# 1    HD214680
# 2    HD186427
# 3    HD146233
# 4         NaN
# ..        ...
# 126       NaN
# 127       NaN
# 128       NaN
# 129       NaN
# 130       NaN
#
# [131 rows x 19 columns]
